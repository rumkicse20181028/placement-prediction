# %%
import pandas as pd

# %%
df=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2        3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3        4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# 211    212      M  58.00   Others  ...         Mkt&Fin  53.62      Placed  275000.0
# 212    213      M  67.00   Others  ...         Mkt&Fin  69.72      Placed  295000.0
# 213    214      F  74.00   Others  ...          Mkt&HR  60.23      Placed  204000.0
# ...

# %%
import numpy as np
import seaborn as sns

# %%
sns.countplot('salary',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('gender',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('status',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(x="salary",y="gender",data=df,ci=None,palette='gray')

# %%
sns.barplot(x='salary',y='status',data=df,ci=None,palette="gray")

# %%
sns.barplot(x='gender',y='salary',hue='status',data=df,ci=None,palette='gray')

# %%
sns.barplot(x='specialisation',y='salary',hue='status',data=df,ci=None,palette='gray')

# %%
sns.boxplot(x='salary',data=df)

# %%
sns.violinplot(x='gender',y='salary',data=df)

# %%
sns.histplot(x='salary',data=df,bins=10)

# %%
sns.histplot(x='specialisation',data=df,bins=5)

# %%
sns.scatterplot(x='status',y='salary',data=df)

# %%
sns.lineplot(data=df,x='salary',y='status',palette='deep')

# %%
sns.lineplot(data=df,x='salary',y='status',palette='rocket')

# %%
sns.scatterplot(x='specialisation',y='salary',data=df)

# %%
sns.violinplot(x='status',y='salary',data=df)

# %%
sns.barplot(x='salary',y='status',data=df,ci=None)

# %%
sns.boxplot(x='gender',y='salary',data=df)

# %%
sns.pairplot(df)

# %%
sns.relplot(x="gender",y="salary",data=df,kind="line")

# %%
sns.lineplot(x='gender',y='specialisation',data=df)

# %%
sns.catplot(x='salary',y='specialisation',kind='violin',data=df)

# %%
df.plot(x='degree_p', y='salary', kind='line')

# %%
df.plot(y='salary', kind='pie', autopct='%1.1f%%')

# %%
df.plot(y='degree_p', labels=df['salary'], kind='pie', autopct='%1.1f%%', legend=False)

# %%
df.plot(x='degree_p', y='salary', kind='bar')

# %%
sns.catplot(x='salary',y='status',data=df,kind='bar')

# %%
sns.heatmap(df.corr(),annot=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Data=df.value_counts().values

# %%
Frequency=df.value_counts().values

# %%
plt.bar(Data,Frequency,color='yellow',width=0.4)
plt.xlabel('salary')
plt.ylabel('status')
plt.title('salary Data')
plt.show()

# %%
plt.bar(Data,Frequency,color='gray',width=0.4)
plt.xlabel('salary')
plt.ylabel('status')
plt.title('salary Data')
plt.show()
